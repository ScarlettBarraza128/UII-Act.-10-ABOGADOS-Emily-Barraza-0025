# %% [markdown]
# <a href="https://colab.research.google.com/github/ScarlettBarraza128/UII-Act.-10-ABOGADOS-Emily-Barraza-0025/blob/main/UII_Act_10_Abogado_Emily_Barraza_0025.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Emily Barraza NL = 7 Fecha/25/mayo/2026
# ### Problema 7
# ## Abogado

# %%
# ==============================================
# IA DE ABOGADOS VIRTUALES
# Uso de:
# Lista de diccionarios
# if, elif, else
# while True
# ciclo for
# ==============================================

# Lista vacía
ListaAbogado = []

# Diccionario vacío
losAbogados = {}

print("====================================")
print("     IA DE ABOGADOS VIRTUALES")
print("====================================")

print("\nEstado inicial del sistema:")
print("ListaAbogado =", ListaAbogado, " ← Lista vacía")
print("losAbogados =", losAbogados, " ← Diccionario vacío")

# Ciclo principal
while True:

    print("\n--------- MENÚ PRINCIPAL ---------")
    print("1. Registrar abogado")
    print("2. Mostrar abogados")
    print("3. Buscar abogado")
    print("4. Eliminar abogado")
    print("5. Estadísticas")
    print("6. Salir")

    opcion = input("Seleccione una opción: ")

    # ==========================================
    # REGISTRAR ABOGADO
    # ==========================================
    if opcion == "1":

        print("\n--- REGISTRO DE ABOGADO ---")

        # Diccionario vacío
        losAbogados = {}

        losAbogados["id"] = input("Ingrese el ID: ")
        losAbogados["nombre"] = input("Ingrese el nombre: ")
        losAbogados["especialidad"] = input("Ingrese la especialidad: ")
        losAbogados["experiencia"] = input("Años de experiencia: ")

        # IA sencilla
        años = int(losAbogados["experiencia"])

        if años >= 15:
            nivel = "Experto"

        elif años >= 7:
            nivel = "Profesional"

        else:
            nivel = "Principiante"

        losAbogados["nivel"] = nivel

        # Guardar en la lista
        ListaAbogado.append(losAbogados)

        print("\n✅ Abogado registrado correctamente.")
        print("Nivel detectado por IA:", nivel)

    # ==========================================
    # MOSTRAR ABOGADOS
    # ==========================================
    elif opcion == "2":

        print("\n--- LISTA DE ABOGADOS ---")

        if len(ListaAbogado) == 0:
            print("No hay abogados registrados.")

        else:

            contador = 1

            for abogado in ListaAbogado:

                print("\nAbogado", contador)
                print("ID:", abogado["id"])
                print("Nombre:", abogado["nombre"])
                print("Especialidad:", abogado["especialidad"])
                print("Experiencia:", abogado["experiencia"])
                print("Nivel IA:", abogado["nivel"])

                contador += 1

    # ==========================================
    # BUSCAR ABOGADO
    # ==========================================
    elif opcion == "3":

        print("\n--- BUSCAR ABOGADO ---")

        buscar = input("Ingrese el nombre del abogado: ")

        encontrado = False

        for abogado in ListaAbogado:

            if abogado["nombre"] == buscar:

                print("\n✅ Abogado encontrado")
                print("ID:", abogado["id"])
                print("Especialidad:", abogado["especialidad"])
                print("Experiencia:", abogado["experiencia"])
                print("Nivel IA:", abogado["nivel"])

                encontrado = True

        if encontrado == False:
            print("❌ No se encontró el abogado.")

    # ==========================================
    # ELIMINAR ABOGADO
    # ==========================================
    elif opcion == "4":

        print("\n--- ELIMINAR ABOGADO ---")

        eliminar = input("Ingrese el nombre del abogado: ")

        eliminado = False

        for abogado in ListaAbogado:

            if abogado["nombre"] == eliminar:

                ListaAbogado.remove(abogado)

                print("✅ Abogado eliminado.")
                eliminado = True

        if eliminado == False:
            print("❌ No existe ese abogado.")

    # ==========================================
    # ESTADÍSTICAS
    # ==========================================
    elif opcion == "5":

        print("\n--- ESTADÍSTICAS ---")

        total = len(ListaAbogado)

        expertos = 0
        profesionales = 0
        principiantes = 0

        for abogado in ListaAbogado:

            if abogado["nivel"] == "Experto":
                expertos += 1

            elif abogado["nivel"] == "Profesional":
                profesionales += 1

            else:
                principiantes += 1

        print("Total de abogados:", total)
        print("Expertos:", expertos)
        print("Profesionales:", profesionales)
        print("Principiantes:", principiantes)

    # ==========================================
    # SALIR
    # ==========================================
    elif opcion == "6":

        print("\nGracias por usar la IA de abogados.")
        break

    # ==========================================
    # OPCIÓN INVÁLIDA
    # ==========================================
    else:
        print("\n❌ Opción inválida.")
# Out:
# ...
#      IA DE ABOGADOS VIRTUALES
# ...
#
# Estado inicial del sistema:
# ListaAbogado = []  ← Lista vacía
# losAbogados = {}  ← Diccionario vacío
#
# --------- MENÚ PRINCIPAL ---------
# 1. Registrar abogado
# 2. Mostrar abogados
# 3. Buscar abogado
# 4. Eliminar abogado
# 5. Estadísticas
# 6. Salir
# Seleccione una opción: 1
#
# --- REGISTRO DE ABOGADO ---
# Ingrese el ID: 1212
# Ingrese el nombre: casandra
# Ingrese la especialidad: familiar
# Años de experiencia: 20
#
# ✅ Abogado registrado correctamente.
# Nivel detectado por IA: Experto
#
# --------- MENÚ PRINCIPAL ---------
# 1. Registrar abogado
# 2. Mostrar abogados
# 3. Buscar abogado
# 4. Eliminar abogado
# 5. Estadísticas
# 6. Salir
# Seleccione una opción: 1
#
# --- REGISTRO DE ABOGADO ---
# Ingrese el ID: 2323
# Ingrese el nombre: luis
# Ingrese la especialidad: divorcio
# Años de experiencia: 5
#
# ✅ Abogado registrado correctamente.
# Nivel detectado por IA: Principiante
#
# --------- MENÚ PRINCIPAL ---------
# ...

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/ScarlettBarraza128/UII-Act.-10-ABOGADOS-Emily-Barraza-0025/refs/heads/main/abogado.png)
